# %% [markdown]
# EJERCICIOS EXTRA EVALUABLES SEMANA 5
# JULIO CESAR ANGELES MENDOZA

# %% [markdown]
# EXTRA 1: Sistema de calificaciones con tuplas
# **Enunciado:** Crea una tupla `calificaciones = (7.5, 9.0, 8.0, 6.5, 10.0)`.
# Imprime la tercera calificación, captura dos calificaciones nuevas con `input()` y
# anéxalas en una nueva tupla. Convierte la nueva tupla en lista, ordénala **de mayor
# a menor** y muestra la suma de todos los elementos usando una función que retorne
# el valor.
# **Entrada:**
# ```
# Nueva calificación 1: 8.5
# Nueva calificación 2: 9.5
# ```
# **Salida:**
# ```
# Tercera calificación: 8.0
# Nueva tupla: (7.5, 9.0, 8.0, 6.5, 10.0, 8.5, 9.5)
# Lista ordenada (mayor a menor): [10.0, 9.5, 9.0, 8.5, 8.0, 7.5, 6.5]
# Suma total: 59.0

# %%
def sumar_personas(lista):
    suma = 0

    for calificacion in lista:
        suma = suma + calificacion

    return suma




calificaciones = (7.5, 9.0, 8.0, 6.5, 10.0)

nueva_calificacion1 = float(input("Nueva calificacion 1: "))
nueva_calificacion2 = float(input("Nueva calificacion 2: "))

nuevas_calificaciones = (nueva_calificacion1, nueva_calificacion2)

nueva_tupla = calificaciones + nuevas_calificaciones

print("Tercera Calificacion:", calificaciones[2])
print("nueva tupla:", nueva_tupla)

lista_de_nombres = list(nueva_tupla)
lista_de_nombres.sort(reverse=True)

print("Lista ordenada(mayor a menor):", lista_de_nombres)
suma_total = sumar_personas(lista_de_nombres)

print("Suma total:", suma_total)
# Out:
# Tercera Calificacion: 8.0
# nueva tupla: (7.5, 9.0, 8.0, 6.5, 10.0, 8.5, 9.5)
# Lista ordenada(mayor a menor): [10.0, 9.5, 9.0, 8.5, 8.0, 7.5, 6.5]
# Suma total: 59.0

# %% [markdown]
# Extra 2: Agenda de contactos con búsqueda
# **Enunciado:** Crea un diccionario `agenda` con tres contactos iniciales (`"Ana":
# "555-0101"`, `"Luis": "555-0102"`, `"Mía": "555-0103"`). Captura un nuevo contacto
# (nombre y teléfono) con `input()` y agrégalo al diccionario. Luego imprime todos
# los nombres con `keys()` en una sola línea y, con una función que retorne el valor,
# busca y muestra el teléfono del nuevo contacto.
# **Entrada:**
# ```
# Nombre del nuevo contacto: Pedro
# Teléfono del nuevo contacto: 555-0140
# Nombre a buscar: Pedro
# ```
# **Salida:**
# ```
# Contactos registrados: Ana, Luis, Mía, Pedro
# El teléfono de Pedro es: 555-0140

# %%
agenda = {
    "Ana": "555-0101",
    "Luis": "555-0102",
    "Mía": "555-0103"
}


Nombre = input("Nombre del nuevo contacto:")
Numero = input("Ingresa el Número del nuevo contacto:")

agenda[Nombre] = Numero

# Busca el numero de telefono
def obtener_telefono(nombre, diccionario_contactos):
    return diccionario_contactos.get(nombre, "Contacto no encontrado")

# Aqui se imprime el Nuevo Diccionario solo con nombres gracias a ".keys".
print(f"Contactos registrados: {', '.join(agenda.keys())}")

telefono_encontrado = obtener_telefono(Nombre, agenda)
print(f"El teléfono de {Nombre} es: {telefono_encontrado}")
# Out:
# Contactos registrados: Ana, Luis, Mía, Pedro
# El teléfono de Pedro es: 555-0140

# %% [markdown]
# Extra 3: Calculadora segura con manejo de excepciones
# **Enunciado:** Escribe un programa que pida dos números enteros. Implementa un
# bloque `try-except` que capture `ValueError` (caracteres no numéricos o vacíos) con
# un mensaje controlado y un bloque específico `except ZeroDivisionError` que muestre
# un mensaje amigable si el segundo número es cero. En caso exitoso, muestra la
# división del primero entre el segundo.
# **Entrada:**
# ```
# Primer número entero: 20
# Segundo número entero: 4
# ```
# **Salida:**
# ```
# 20 dividido entre 4 es: 5.0
# ```
# **Caso de error (divisor cero):**
# ```
# Primer número entero: 10
# Segundo número entero: 0
# ```
# **Salida:**
# ```
# Error: No es posible dividir entre cero. Ingresa un divisor distinto de 0.

# %%
try:
    numero1 = int(input("Ingresa el primer número: "))
    numero2 = int(input("Ingresa el segundo número: "))

    print(f"{numero1} divido entre {numero2} es", numero1 / numero2)

except ZeroDivisionError:
    print("Error: No es posible dividir entre cero. Ingresa un divisor distinto a cero")
# Out:
# Error: No es posible dividir entre cero. Ingresa un divisor distinto a cero

# %% [markdown]
#  Extra 4: Analizador de mensajes con strings
# **Enunciado:** Crea una variable `mensaje = "Python es un lenguaje poderoso"`.
# Imprime su longitud con `len()`, conviértelo a mayúsculas, reemplaza la palabra
# `"Python"` por `"programación"` y, con una función que retorne el conteo, muestra
# cuántas palabras contiene el mensaje original.
# **Entrada:**
# ```
# mensaje = "Python es un lenguaje poderoso"
# ```
# **Salida:**
# ```
# Longitud del mensaje: 30
# En mayúsculas: PYTHON ES UN LENGUAJE PODEROSO
# Texto reemplazado: programación es un lenguaje poderoso
# Palabras totales: 5

# %%
def contar_palabras(mensaje):
    palabras = mensaje.split()
    return len(palabras)

frase = "Python es un lenguaje poderoso"

print("longitud del menaaje:", len(frase))
mayusculas = frase.upper()
print("En mayúsculas:", mayusculas)
texto_reemplazado = frase.replace("Python", "programación")
print("Texto reemplazado:", texto_reemplazado)
total_palabras = contar_palabras(frase)
print("Palabras totales:", total_palabras)
# Out:
# longitud del menaaje: 30
# En mayúsculas: PYTHON ES UN LENGUAJE PODEROSO
# Texto reemplazado: programación es un lenguaje poderoso
# Palabras totales: 5

# %% [markdown]
# EJERCCIOS DE PRACTICA, AHORA EVALUABLES

# %% [markdown]
# Desafío Extra 1: Lista de espera con tuplas
# Crea una tupla `espera = ("María", "José", "Carlos", "Lucía", "Pedro")`. Imprime el
# tercer elemento, captura dos nombres nuevos con `input()`, anéxalos en una nueva
# tupla, conviértela en lista, ordénala alfabéticamente y muestra la cantidad total
# de personas.

# %%
espera = ("Maria", "Jose", "Carlos", "Lucia","Pedro")

nuevo_name1 = input("INGRESA EL PRIMER NUEVO NOMBRE: ")
nuevo_name2 = input("INGRESA EL SEGUNDO NUEVO NOMBRE: ")

nuevos_nombres = (nuevo_name1, nuevo_name2)

nueva_tupla = espera + nuevos_nombres

print("Tercer Nombre:", espera[2])
print("nueva tupla:", nueva_tupla)

lista_de_nombres = list(nueva_tupla)
lista_de_nombres.sort(reverse=True)

print("Lista ordenada (alfabeticamente):", lista_de_nombres)
suma_total = len(nueva_tupla)

print("Total de personas:", suma_total)
# Out:
# Tercer Nombre: Carlos
# nueva tupla: ('Maria', 'Jose', 'Carlos', 'Lucia', 'Pedro', 'Julio', 'Leonardo')
# Lista ordenada (alfabeticamente): ['Pedro', 'Maria', 'Lucia', 'Leonardo', 'Julio', 'Jose', 'Carlos']
# Total de personas: 7

# %% [markdown]
# Desafío Extra 2: Contador de votos con diccionario
# Crea un diccionario `votos = {"Rojo": 0, "Azul": 0, "Verde": 0}`. Pide al usuario
# el color de su voto cinco veces, suma uno al valor correspondiente en cada ocasión
# y, al final, imprime con `items()` el color ganador junto con su total

# %%
votos ={
    "ROJO": 0,
    "AZUL": 0,
    "VERDE": 0
}

cantidad = int(input("Cuantos van a ser?"))
conteo = 1

if cantidad > 5:
    print("solo se pueden agregar maximo 5 votos")
else:
    while conteo <= cantidad: 
        voto = input(f"ingrese el voto {conteo} (ROJO, AZUL o VERDE): ")
        print(f"votaste por {voto.upper()} ")
        if voto.upper() in votos:
            print(f"el voto para {voto.upper()}")
            votos[voto.upper()] += 1
            conteo += 1
        else:
            print("el voto no es valido")

    print("\tRESULTADOS:")
    for k,v in votos.items():
        print(f"opcion {k}, votos: {v}")
        ganador = max(votos, key=votos.get)

    print("El ganador es:", ganador)
# Out:
# votaste por ROJO
# el voto para ROJO
# votaste por ROJO
# el voto para ROJO
# votaste por ROJO
# el voto para ROJO
# votaste por AZUL
# el voto para AZUL
# votaste por VERDE
# el voto para VERDE
# 	RESULTADOS:
# opcion ROJO, votos: 3
# opcion AZUL, votos: 1
# opcion VERDE, votos: 1
# El ganador es: ROJO

# %% [markdown]
# Desafío Extra 3: Validación robusta de entrada
# Escribe un programa que pida al usuario dos números enteros dentro de un bloque
# `try-except`. Si el usuario ingresa texto o un valor vacío, muestra un mensaje
# controlado y repite la solicitud con un ciclo `while`. Luego pide la división del
# primero entre el segundo, con un bloque específico para `ZeroDivisionError`

# %%
while True:
    try: 
        num1 = int(input("ingresa el primer numero: "))
        num2 = int(input("ingresa el segundo numero: "))
        break

    except ValueError:
        print("ERROR: debes ingresar un numero entero")
        print("Intenta de nuevo")

try:
    division = num1 / num2
    print("El resultado de la division es: ", division)

except ZeroDivisionError:
    print("ERROR: el numero no es divisible entre cero")
    print("ingresa un nuevo divisor")
# Out:
# ERROR: el numero no es divisible entre cero
# ingresa un nuevo divisor

# %% [markdown]
# Desafío Extra 4: Analizador de textos
# Crea un programa que reciba una frase, imprima su longitud con `len()`, la
# convierta a mayúsculas, reemplace la palabra "Python" por "programación" y muestre
# cuántas palabras contiene usando una función que retorne el conteo.

# %%
def contar_palabras(mensaje):
    palabras = mensaje.split()
    return len(palabras)


mensaje = "Python me gusta muchisimo"

print("Longitud del mensaje:", len(mensaje))

mayusculas = mensaje.upper()
print("En mayúsculas:", mayusculas)

texto_reemplazado = mensaje.replace("Python", "programación")
print("Texto reemplazado:", texto_reemplazado)

total_palabras = contar_palabras(mensaje)
print("Palabras totales:", total_palabras)
# Out:
# Longitud del mensaje: 25
# En mayúsculas: PYTHON ME GUSTA MUCHISIMO
# Texto reemplazado: programación me gusta muchisimo
# Palabras totales: 4

# %% [markdown]
# Desafío Extra 5: Minimenú modular integrador
# Construye un menú con un ciclo `while` y opciones numéricas que permita ejecutar de
# forma modular: (1) mostrar la tupla de números ordenada, (2) buscar un teléfono en
# el diccionario `contactos`, (3) dividir dos números con manejo de
# `ZeroDivisionError` y (4) analizar un mensaje de texto. La opción (5) debe
# finalizar el programa.

# %%
def ordenar_numeros():
    numeros = (8,3,10,2,7,5)

    lista_numeros = list(numeros)
    lista_numeros.sort()

    print("Numeros ordenados: ", lista_numeros)

def buscar_telefono():
    contactos = {
        "RAUL": "4421234567",
        "CARLOS": "4429876543",
        "ANA": "4424567890"
    }

    nombre = input("Ingrese el nombre de contactos:  ")
    if nombre.upper() in contactos:
        print("telefono", contactos[nombre.upper()])
    else:
        print("Contacto no encontrado. ")


def dividir_numeros():
    try:
        numero_uno = float(input("ingresa el primer número: "))
        numero_dos = float(input("Ingresa el segundo número: "))

        división = numero_uno / numero_dos

        print("Resultado: ", division)

    except ZeroDivisionError:
        print("ERROR: No se puede dividir entre cero")


    except ValueError:
        print("ERROR: Debes ingresar numeros ")

def analizar_mensaje():
    mensaje = input("ingresa un mensaje: ")

    print("longitud del mensaje:", len(mensaje))

    mayusculas = mensaje.upper()
    print("En mayusculas: ", mayusculas)

    palabras = mensaje.split()
    print("Total de palabras", len(palabras))

while True:

    print("\n-----------MENU PRINCIPAL----------")
    print("1. Mostrar numeros ordenados")
    print("2. Buscar telefono")
    print("3. Dividir dos numeros")
    print("4. Analizar mensaje") 
    print("5. Salir") 

    opcion = int(input("Selecciona una opcion (1-5):"))

    match opcion:

        case 1:
            ordenar_numeros()

        case 2:
            buscar_telefono()

        case 3:
            dividir_numeros()

        case 4:
            analizar_mensaje()

        case 5:
            print("Programa finalizado")
            break

        case _:
            print("Opcion no valida")
# Out:
# -----------MENU PRINCIPAL----------
# 1. Mostrar numeros ordenados
# 2. Buscar telefono
# 3. Dividir dos numeros
# 4. Analizar mensaje
# 5. Salir
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 59
#      55     print("3. Dividir dos numeros")
#      56     print("4. Analizar mensaje")
#      57     print("5. Salir")
#      58
# ---> 59     match opcion:
#      60
#      61         case 1:
#      62             ordenar_numeros()
#
# NameError: name 'opcion' is not defined
