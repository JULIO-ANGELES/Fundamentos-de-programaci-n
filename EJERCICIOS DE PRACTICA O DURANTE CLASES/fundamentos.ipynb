# %% [markdown]
# SEMANA 1 PRIMERA PRACTICA

# %%
print("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# VARIABLES DE PYTHON CON TIPOS DE DATOS QUE TIENEN DIFERENTE FORMA NUMERICA ENTEROS FLOTANTE CADENA DE CARACTERES COMPUESTOS BOOLEANOS

# %%
nombre = "Julio"
Edad = "18"
es_estudiante = True
Esta_activo = False 

print(type(nombre))
print(type(Edad))
print(type(es_estudiante))
print(type(Esta_activo))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'bool'>
# <class 'bool'>

# %%
nombre  = "Julio"
Edad = "18"

print("hola",nombre, "tienes", Edad, "años")
# Out:
# hola Julio tienes 18 años

# %% [markdown]
# AQUI INICIA GIT

# %% [markdown]
# ALGORITMO PARA CALCULAR LA VELOCIDAD

# %%
distancia = int(input("Ingrese la distancia en kilometros: "))
tiempo = int(input("Ingrese el tiempo en horas: "))

print("el dato distancia es de tipo: ", type(distancia))
print("el dato tiempo es de tipo: ", type(tiempo))
velocidad = distancia / tiempo
print("La velocidad promedio es:", velocidad, "km/h")
# Out:
# el dato distancia es de tipo:  <class 'int'>
# el dato tiempo es de tipo:  <class 'int'>
# La velocidad promedio es: 7.0 km/h

# %% [markdown]
# ENTRADA Y SALIDAS

# %%
nombre = input("ingrese su nombre:")
edad = int(input("ingrese su edad:"))

print("Hola, buenos dias", nombre, "de", edad, "años", "Como estas?" )
# Out:
# Hola, buenos dias julio de 18 años Como estas?
