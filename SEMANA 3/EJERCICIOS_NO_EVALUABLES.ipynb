# %% [markdown]
# EJERCICIOS PARA PRACTICAR (SEMANA 3)
# 1:

# %%
Monto = float(input("Ingresa el monto de total de tu compra"))

if Monto >= 300:
    Descuento = Monto * 0.10
    Monto_final = Monto - Descuento
    print(f"Monto total: {Monto}$ \nDescuento del 10% : -{Descuento}$ \nMonto final a pagar: {Monto_final}$")
else:
    print(f"Monto total: {Monto}$ \nDescuento: No aplica \nMonto fina a pagar: {Monto}$")

# %% [markdown]
# Numeros negativos y positivos

# %%
Num = int(input("Ingresa cualquer número:"))

if Num >= 0:
    print(f"El número {Num} es positivo")
else:
    print(f"El número {Num} es negativo")

# %% [markdown]
# EJERCICIO 7, DESGLOSE DE BILLETES

# %%
cantidad = int(input("Ingrese la cantidad (Multiplo de 10): "))
billetes_500 = cantidad //500
cantidad = cantidad % 500

billetes_200 = cantidad//200
cantidad = cantidad % 200

billetes_100 = cantidad //100
cantidad = cantidad % 100

billetes_50 = cantidad //50
cantidad = cantidad % 50

billetes_50 = cantidad //20
cantidad = cantidad % 20

monedas_10 = cantidad //10
cantidad = cantidad % 10

print(f"hay {billetes_500} billetes de 500")
print(f"hay {billetes_200} billetes de 200")
print(f"hay {billetes_100} billetes de 100")
# Out:
# hay 100 billetes de 500
